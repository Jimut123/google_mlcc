# %% [markdown]
# # Introduction

# %% [markdown]
# This is the final task of MLCC. Make a clone of this notebook, complete the task, and submit to us.
#
# ### Team members' name:  _FIll me up_

# %% [markdown]
# In this task, we'll be using the Breast cancer dataset that comes prebuilt with sklearn. The first part is usual improting routine.

# %%
import math

from IPython import display
from matplotlib import cm
from matplotlib import gridspec
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
from sklearn import metrics
import tensorflow as tf
from tensorflow.python.data import Dataset

tf.logging.set_verbosity(tf.logging.ERROR)
pd.options.display.max_rows = 10
pd.options.display.float_format = '{:.1f}'.format

# %% [markdown]
# Here we load the dataset from sklearn

# %%
from sklearn.datasets import load_breast_cancer

breast_cancer = load_breast_cancer()
print(breast_cancer.DESCR)

# %% [markdown]
# We will convert the dataset to a Pandas dataframe. We will set the CLASS column as our target. We want to predict if a cancer is malignant (0) or benign (1)

# %%
breast_cancer_dataframe = pd.DataFrame(breast_cancer.data)
breast_cancer_dataframe.columns = breast_cancer.feature_names
breast_cancer_dataframe['CLASS'] = breast_cancer.target

# %%
breast_cancer_dataframe.describe()

# %% [markdown]
# # TASK 1: Implement a logistic regression

# %% [markdown]
# Implement a logistic regressor and train on the dataset. Try to get the LogLoss to be as low as possible, without overfitting.
# Here's the Logistic Regression notebook for reference (https://colab.research.google.com/notebooks/mlcc/logistic_regression.ipynb)

# %% [markdown]
# # TASK 2: Calculate the Accuracy and plot the ROC for the model

# %% [markdown]
# Calculate the accuracy of your model, and plot an ROC curve.

# %% [markdown]
# # TASK 3: Calculate the precision and recall for your model

# %% [markdown]
# Calculate the precision and recall for your model.

# %% [markdown]
# # TASK 4: Answer the questions

# %% [markdown]
# ## Note that we do not have a test data, so all the questions should be answered keeping the training data in mind

# %% [markdown]
# ### 1) Is Accuracy a good measure of the performance of the model in this case? Why, or why not?

# %% [markdown]
# Answer:

# %% [markdown]
# ### 2) Generally we want both precision and recall to be high, but both cannot be increased together. Between high precision and high recall, which one is preferred here? In other words, between precision and recall which one is a good measure for us? Why?

# %% [markdown]
# Answer:

# %% [markdown]
# Created by Aniket Bhattacharyea (aniketmail669@gmail.com)
